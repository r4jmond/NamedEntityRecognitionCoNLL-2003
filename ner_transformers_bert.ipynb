# %% [markdown]
# ## install dependencies

# %%
# %pip install seqeval
# %pip install transformers
# %pip install datasets
# %pip install numpy
# %pip install evaluate
# Out:
# /usr/bin/fish: /home/r4jmund/soft/miniconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /usr/bin/fish)
# Requirement already satisfied: seqeval in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.14.0 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from seqeval) (1.23.5)
# Requirement already satisfied: scikit-learn>=0.21.3 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from seqeval) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from scikit-learn>=0.21.3->seqeval) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from scikit-learn>=0.21.3->seqeval) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from scikit-learn>=0.21.3->seqeval) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.
# /usr/bin/fish: /home/r4jmund/soft/miniconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /usr/bin/fish)
# Requirement already satisfied: transformers in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (4.30.2)
# Requirement already satisfied: filelock in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from transformers) (0.15.1)
# Requirement already satisfied: numpy>=1.17 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from transformers) (5.4.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from transformers) (0.3.1)
# Requirement already satisfied: tqdm>=4.27 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.6.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from requests->transformers) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from requests->transformers) (2023.5.7)
# Note: you may need to restart the kernel to use updated packages.
# /usr/bin/fish: /home/r4jmund/soft/miniconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /usr/bin/fish)
# Requirement already satisfied: datasets in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (2.13.1)
# Requirement already satisfied: numpy>=1.17 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from datasets) (12.0.1)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from datasets) (0.3.6)
# Requirement already satisfied: pandas in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from datasets) (2.0.2)
# Requirement already satisfied: requests>=2.19.0 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from datasets) (4.65.0)
# Requirement already satisfied: xxhash in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from datasets) (3.2.0)
# Requirement already satisfied: multiprocess in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from datasets) (3.8.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from datasets) (0.15.1)
# Requirement already satisfied: packaging in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from datasets) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from datasets) (5.4.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from aiohttp->datasets) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.6.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (2023.5.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# /usr/bin/fish: /home/r4jmund/soft/miniconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /usr/bin/fish)
# Requirement already satisfied: numpy in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (1.23.5)
# Note: you may need to restart the kernel to use updated packages.
# /usr/bin/fish: /home/r4jmund/soft/miniconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /usr/bin/fish)
# Requirement already satisfied: evaluate in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (0.4.0)
# Requirement already satisfied: datasets>=2.0.0 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from evaluate) (2.13.1)
# Requirement already satisfied: numpy>=1.17 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from evaluate) (1.23.5)
# Requirement already satisfied: dill in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from evaluate) (0.3.6)
# Requirement already satisfied: pandas in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from evaluate) (2.0.2)
# Requirement already satisfied: requests>=2.19.0 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from evaluate) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from evaluate) (4.65.0)
# Requirement already satisfied: xxhash in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from evaluate) (3.2.0)
# Requirement already satisfied: multiprocess in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from evaluate) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from evaluate) (2023.6.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from evaluate) (0.15.1)
# Requirement already satisfied: packaging in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from evaluate) (23.0)
# Requirement already satisfied: responses<0.19 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from evaluate) (0.18.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from datasets>=2.0.0->evaluate) (12.0.1)
# Requirement already satisfied: aiohttp in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from datasets>=2.0.0->evaluate) (3.8.4)
# Requirement already satisfied: pyyaml>=5.1 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from datasets>=2.0.0->evaluate) (5.4.1)
# Requirement already satisfied: filelock in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from huggingface-hub>=0.7.0->evaluate) (3.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.6.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from requests>=2.19.0->evaluate) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from requests>=2.19.0->evaluate) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from requests>=2.19.0->evaluate) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from requests>=2.19.0->evaluate) (2023.5.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from pandas->evaluate) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from pandas->evaluate) (2023.3)
# Requirement already satisfied: attrs>=17.3.0 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: six>=1.5 in /home/r4jmund/soft/miniconda3/envs/tf/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Basic imports and parameters

# %%
import tensorflow as tf
from pathlib import Path

START_MODEL_CHECKPOINT = "bert-base-cased"
TRAIN_BATCH_SIZE = 10
TRAIN_EPOCHS = 10

BEST_MODEL_CHECKPOINT = Path('./model/best_model.h5')

# Parameters for learning rate - we use linear decay for learning rate
INITIAL_LEARNING_RATE = 1e-5
WEIGHT_DECAY_RATE = 0.01

# %% [markdown]
# ## GPU config for optimal memory usage

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
  tf.config.experimental.set_memory_growth(gpu, True)

# %% [markdown]
# ## Loading dataset

# %%
from datasets import load_dataset

raw_datasets = load_dataset("conll2003")
# Out:
# Found cached dataset conll2003 (/home/r4jmund/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98)
# 100%|██████████| 3/3 [00:00<00:00, 805.46it/s]

# %% [markdown]
# ### Dataset preview

# %%
raw_datasets, raw_datasets["train"][0]["tokens"], raw_datasets["train"][0]["ner_tags"]
# Out:
# (DatasetDict({
#      train: Dataset({
#          features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#          num_rows: 14041
#      })
#      validation: Dataset({
#          features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#          num_rows: 3250
#      })
#      test: Dataset({
#          features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#          num_rows: 3453
#      })
#  }),
#  ['EU', 'rejects', 'German', 'call', 'to', 'boycott', 'British', 'lamb', '.'],
#  [3, 0, 7, 0, 0, 0, 7, 0, 0])

# %% [markdown]
# ### Print label names

# %%
ner_feature = raw_datasets["train"].features["ner_tags"]
label_names = ner_feature.feature.names
ner_feature, label_names
# Out:
# (Sequence(feature=ClassLabel(names=['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC', 'B-MISC', 'I-MISC'], id=None), length=-1, id=None),
#  ['O',
#   'B-PER',
#   'I-PER',
#   'B-ORG',
#   'I-ORG',
#   'B-LOC',
#   'I-LOC',
#   'B-MISC',
#   'I-MISC'])

# %% [markdown]
# ### Dataset preview - first record with full label names

# %%
words = raw_datasets["train"][0]["tokens"]
labels = raw_datasets["train"][0]["ner_tags"]
line1 = ""
line2 = ""
for word, label in zip(words, labels):
    full_label = label_names[label]
    max_length = max(len(word), len(full_label))
    line1 += word + " " * (max_length - len(word) + 1)
    line2 += full_label + " " * (max_length - len(full_label) + 1)

print(line1)
print(line2)
# Out:
# EU    rejects German call to boycott British lamb .
# B-ORG O       B-MISC O    O  O       B-MISC  O    O

# %% [markdown]
# ## Creating tokenizer

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(START_MODEL_CHECKPOINT)

# %% [markdown]
# ### Tokenizer - test

# %%
inputs = tokenizer(raw_datasets["train"][0]["tokens"], is_split_into_words=True)
inputs.tokens()
# Out:
# ['[CLS]',
#  'EU',
#  'rejects',
#  'German',
#  'call',
#  'to',
#  'boycott',
#  'British',
#  'la',
#  '##mb',
#  '.',
#  '[SEP]']

# %% [markdown]
# ### Aligning labels with tokens - after tokenizer
#
# We use tokenizer for sub-word tokenization, but that means we need to align NER labels accordingly. This is what function below does - it takes labels and word_ids, which is list of word IDs as an argument. word_ids can be obtained from the Dataset class using its method word_ids.

# %%
def align_labels_with_tokens(labels, word_ids):
    new_labels = []
    current_word = None
    for word_id in word_ids:
        if word_id != current_word:
            # Start of a new word!
            current_word = word_id
            label = -100 if word_id is None else labels[word_id]
            new_labels.append(label)
        elif word_id is None:
            # Special token
            new_labels.append(-100)
        else:
            # Same word as previous token
            label = labels[word_id]
            # If the label is B-XXX we change it to I-XXX
            if label % 2 == 1:
                label += 1
            new_labels.append(label)

    return new_labels

# %% [markdown]
# ### Aligning labels test
#
# As we can see, after calling align_labels_with_tokens, new labels are aligned with the tokenized inputs.

# %%
labels = raw_datasets["train"][0]["ner_tags"]
word_ids = inputs.word_ids()
print(labels)
print(align_labels_with_tokens(labels, word_ids))
# Out:
# [3, 0, 7, 0, 0, 0, 7, 0, 0]
# [-100, 3, 0, 7, 0, 0, 0, 7, 0, 0, 0, -100]

# %% [markdown]
# ## Tokenizing and aligning labels on the whole dataset
#
# Here we tokenize and align whole label using previously instantiated tokenizer. We do that using map function for efficient batched data processing.
# We automatically truncate the input to the maximum model input size, but padding is being done during training.

# %%
def tokenize_and_align_labels(dataset):
    tokenized_inputs = tokenizer(
        dataset["tokens"], truncation=True, is_split_into_words=True
    )
    all_labels = dataset["ner_tags"]
    new_labels = []
    for i, labels in enumerate(all_labels):
        word_ids = tokenized_inputs.word_ids(i)
        new_labels.append(align_labels_with_tokens(labels, word_ids))

    tokenized_inputs["labels"] = new_labels
    return tokenized_inputs

# %%
tokenized_datasets = raw_datasets.map(
    tokenize_and_align_labels,
    batched=True,
    remove_columns=raw_datasets["train"].column_names,
)
# Out:
# Loading cached processed dataset at /home/r4jmund/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98/cache-26d057f0f1662018.arrow
# Loading cached processed dataset at /home/r4jmund/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98/cache-c87b2ef1e5f67e1d.arrow
# Loading cached processed dataset at /home/r4jmund/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98/cache-ba39b941f4bb174f.arrow

# %% [markdown]
# ## Instantiating DataCollator for dynamic input padding

# %%
from transformers import DataCollatorForTokenClassification

data_collator = DataCollatorForTokenClassification(
    tokenizer=tokenizer, return_tensors="tf"
)

# %%
# DataCollator test on the dataset first two rows.

print ("First two rows before padding:")
for i in range(2):
    print(tokenized_datasets["train"][i]["labels"])

print ("First two rows after padding:")
batch = data_collator([tokenized_datasets["train"][i] for i in range(2)])
print(batch["labels"])
print ("Works as intended :)")
# Out:
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# First two rows before padding:
# [-100, 3, 0, 7, 0, 0, 0, 7, 0, 0, 0, -100]
# [-100, 1, 2, -100]
# First two rows after padding:
# tf.Tensor(
# [[-100    3    0    7    0    0    0    7    0    0    0 -100]
#  [-100    1    2 -100 -100 -100 -100 -100 -100 -100 -100 -100]], shape=(2, 12), dtype=int64)
# Works as intended :)

# %% [markdown]
# ## Final data preparation - creating tf.data.Dataset from the underlying Dataset
#
# Here we cast the Dataset type to the one accepted by Keras. We also specify our data collator for dynamic padding and select batch_size.

# %%
tf_train_dataset = tokenized_datasets["train"].to_tf_dataset(
    columns=["attention_mask", "input_ids", "labels", "token_type_ids"],
    collate_fn=data_collator,
    shuffle=True,
    batch_size=TRAIN_BATCH_SIZE,
)

tf_eval_dataset = tokenized_datasets["validation"].to_tf_dataset(
    columns=["attention_mask", "input_ids", "labels", "token_type_ids"],
    collate_fn=data_collator,
    shuffle=False,
    batch_size=TRAIN_BATCH_SIZE,
)

# %%
# Dictionaries for easy id2label and label2id conversion
id2label = {i: label for i, label in enumerate(label_names)}
label2id = {v: k for k, v in id2label.items()}
id2label, label2id
# Out:
# ({0: 'O',
#   1: 'B-PER',
#   2: 'I-PER',
#   3: 'B-ORG',
#   4: 'I-ORG',
#   5: 'B-LOC',
#   6: 'I-LOC',
#   7: 'B-MISC',
#   8: 'I-MISC'},
#  {'O': 0,
#   'B-PER': 1,
#   'I-PER': 2,
#   'B-ORG': 3,
#   'I-ORG': 4,
#   'B-LOC': 5,
#   'I-LOC': 6,
#   'B-MISC': 7,
#   'I-MISC': 8})

# %% [markdown]
# ## Model instantiation

# %%
from transformers import TFAutoModelForTokenClassification

model = TFAutoModelForTokenClassification.from_pretrained(
    START_MODEL_CHECKPOINT,
    id2label=id2label,
    label2id=label2id,
)
# Out:
# All PyTorch model weights were used when initializing TFBertForTokenClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForTokenClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model.config.num_labels
# Should be 9 - our model has to have the same number of labels as dataset for optimal results
# Out:
# 9

# %% [markdown]
# ## Creating optimizer for training, compiling model

# %%
from transformers import create_optimizer

# Train in mixed-precision float16
# Comment this line out if you're using a GPU that will not benefit from this
tf.keras.mixed_precision.set_global_policy("mixed_float16")

# The number of training steps is the number of samples in the dataset, divided by the batch size then multiplied
# by the total number of epochs. Note that the tf_train_dataset here is a batched tf.data.Dataset,
# not the original Hugging Face Dataset, so its len() is already num_samples // batch_size.
num_train_steps = len(tf_train_dataset) * TRAIN_EPOCHS

optimizer, schedule = create_optimizer(
    init_lr=INITIAL_LEARNING_RATE,
    num_warmup_steps=0,
    num_train_steps=num_train_steps,
    weight_decay_rate=WEIGHT_DECAY_RATE,
)
model.compile(optimizer=optimizer, metrics=["accuracy"])
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce GTX 1660 Ti with Max-Q Design, compute capability 7.5
# 2023-07-30 01:50:31.602152: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %% [markdown]
# ## Defining metrics calculation function

# %%
import numpy as np
import evaluate

metric = evaluate.load("seqeval")
def calculate_metrics(model, dataset):

    all_predictions = []
    all_labels = []
    for batch in dataset:
        logits = model.predict_on_batch(batch)["logits"]
        labels = batch["labels"]
        predictions = np.argmax(logits, axis=-1)
        for prediction, label in zip(predictions, labels):
            for predicted_idx, label_idx in zip(prediction, label):
                if label_idx == -100:
                    continue
                all_predictions.append(label_names[predicted_idx])
                all_labels.append(label_names[label_idx])
    return metric.compute(predictions=[all_predictions], references=[all_labels])

# %% [markdown]
# ## Creating callback for saving the best model

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=BEST_MODEL_CHECKPOINT,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %% [markdown]
# ### Evaluating model performance with randomly initialized head - just for comparison as a starting point

# %%
initial_metrics = calculate_metrics(model, tf_eval_dataset)
initial_metrics
# Out:
# 2023-07-30 01:26:19.182400: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,48]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:23.215393: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,52]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:25.523315: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,49]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:25.847170: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,17]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:25.967901: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,18]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:26.089763: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,16]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:26.201870: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,51]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:26.504639: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,30]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:26.685737: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,49]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:27.052968: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,46]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:27.315006: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,44]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:27.574463: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,17]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:27.686247: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,30]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:27.895324: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,19]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:28.017031: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,36]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:28.236751: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,76]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:28.684964: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,71]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:29.104271: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,15]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:29.210738: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,17]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:29.324629: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,14]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:29.423489: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,16]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:29.532955: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,26]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:29.705913: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,15]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:29.817777: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,57]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:30.155769: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,60]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:30.512748: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,28]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:30.688005: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,37]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:30.913267: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,40]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:31.148958: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,36]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:31.365122: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,51]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:31.669856: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,56]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:32.005893: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,52]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:32.326223: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,47]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:32.603973: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,21]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:32.750237: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,18]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:32.886706: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,18]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:33.013228: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,20]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:33.143894: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,17]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:33.260571: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,18]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:33.393556: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,19]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:33.547543: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,18]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:33.691406: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,17]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:33.807865: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,18]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:33.931780: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,17]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:34.057407: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,19]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:34.232154: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,16]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:34.348818: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,38]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:34.596845: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,54]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:34.959721: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,50]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:35.266229: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,25]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:35.444379: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,36]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:35.677681: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,17]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:35.787612: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,36]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:36.030780: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,23]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:36.184562: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,42]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:36.450798: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,45]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:36.746608: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,19]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:36.877612: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,43]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:37.137381: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,54]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:37.467451: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,57]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:37.806491: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,95]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:38.323343: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,46]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:38.599646: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,51]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:38.904924: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,54]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:39.222175: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,71]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:39.653333: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,48]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:39.916182: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,38]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:40.143196: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,41]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:40.386274: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,49]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:40.686029: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,51]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:40.982933: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,44]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:41.251847: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,52]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:41.559810: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,49]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:41.864438: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,48]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:42.146967: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,48]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:42.444788: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,37]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:42.684636: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,51]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:43.011654: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,45]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:43.315025: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,62]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:43.694832: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,59]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:44.066552: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,48]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:44.335312: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,69]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:44.737488: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,58]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:45.075676: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,51]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:45.390776: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,58]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:45.737684: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,50]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:46.039443: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,65]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:46.417692: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,66]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:46.817633: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,39]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:47.056907: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,50]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:47.358308: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,67]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:47.736259: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,53]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:48.044181: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,61]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:48.398174: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,55]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:48.734919: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,65]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:49.126437: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,54]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:49.447064: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,54]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:49.770056: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,59]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:50.130520: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,49]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:50.438046: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,68]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:50.861436: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,50]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:51.157495: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,56]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:51.502161: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,49]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:51.801804: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,43]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:52.054134: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,37]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:52.273737: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,38]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:52.502132: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,56]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:52.840272: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,33]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:53.044214: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,17]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:53.156629: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,31]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:53.347398: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,47]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:53.617680: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,45]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:53.892185: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,49]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:54.179447: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,40]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:54.462708: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,25]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:54.625892: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,6]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:54.680837: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,37]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:54.911414: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,38]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:55.146716: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,50]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:55.450167: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,62]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:55.819124: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,61]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:56.177671: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,62]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:56.533495: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,54]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:56.856869: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,48]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:57.123522: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,59]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:57.473094: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,45]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:57.735979: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,52]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:58.039071: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,37]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:58.263568: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,45]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:58.553146: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,43]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:58.810658: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,57]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:59.139385: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,38]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:59.388688: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,56]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:59.720202: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,22]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:26:59.856008: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,38]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:00.095725: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,54]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:00.424448: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,61]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:00.788801: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,47]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:01.062415: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,43]
# 	 [[{{node Placeholder/_3}}]]
# ...
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:23.452210: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,36]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:23.682951: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,43]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:23.945280: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,43]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:24.230757: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,44]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:24.525305: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,35]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:24.743978: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,52]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:25.070482: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,38]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:25.318792: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,46]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:25.598691: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,60]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:25.957521: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,61]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:26.305989: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,54]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:26.621842: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,62]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:26.982009: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,54]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:27.297445: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,51]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:27.597028: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,83]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:28.088569: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,45]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:28.374387: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,46]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:28.639283: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,50]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:28.934079: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,41]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:29.179723: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,54]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:29.496413: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,45]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:29.765045: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,42]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:30.009957: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,57]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:30.338686: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,49]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:30.638181: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,44]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:30.906630: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,50]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:31.204043: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,49]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:31.497634: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,66]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:31.895590: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,53]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:32.195809: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,68]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:32.661762: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,37]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:32.878014: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,56]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:33.206152: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,43]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:33.454746: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,57]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:33.792953: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,59]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:34.139535: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,72]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:34.562849: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,53]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:34.903882: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,43]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:35.169321: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,59]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:35.514760: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,53]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:35.825290: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,57]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:36.177830: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,43]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:36.442306: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [12,43]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 01:27:36.703936: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,55]
# 	 [[{{node Placeholder/_3}}]]
# {'LOC': {'precision': 0.0121667098110277,
#   'recall': 0.05117038649972782,
#   'f1': 0.019659102792010878,
#   'number': 1837},
#  'MISC': {'precision': 0.00683311432325887,
#   'recall': 0.05639913232104121,
#   'f1': 0.012189404594467886,
#   'number': 922},
#  'ORG': {'precision': 0.0006925207756232687,
#   'recall': 0.0037285607755406414,
#   'f1': 0.0011680878402055834,
#   'number': 1341},
#  'PER': {'precision': 0.0053711253478289,
#   'recall': 0.04505971769815418,
#   'f1': 0.009598149754264238,
#   'number': 1842},
#  'overall_precision': 0.006156436633428925,
#  'overall_recall': 0.03938067990575564,
#  'overall_f1': 0.010648221883461128,
#  'overall_accuracy': 0.2086889974686525}

# %% [markdown]
# ## Fitting the model

# %%
model.fit(
    tf_train_dataset,
    validation_data=tf_eval_dataset,
    epochs=TRAIN_EPOCHS,
    callbacks=[model_checkpoint_callback]
)
# Out:
# Epoch 1/10
# 1405/1405 [==============================] - 280s 189ms/step - loss: 0.1872 - accuracy: 0.4081 - val_loss: 0.0735 - val_accuracy: 0.4875
# Epoch 2/10
# 1405/1405 [==============================] - 259s 184ms/step - loss: 0.0553 - accuracy: 0.4268 - val_loss: 0.0659 - val_accuracy: 0.4884
# Epoch 3/10
# 1405/1405 [==============================] - 257s 183ms/step - loss: 0.0348 - accuracy: 0.4297 - val_loss: 0.0535 - val_accuracy: 0.4908
# Epoch 4/10
# 1405/1405 [==============================] - 264s 188ms/step - loss: 0.0223 - accuracy: 0.4307 - val_loss: 0.0564 - val_accuracy: 0.4910
# Epoch 5/10
# 1405/1405 [==============================] - 265s 189ms/step - loss: 0.0156 - accuracy: 0.4292 - val_loss: 0.0569 - val_accuracy: 0.4912
# Epoch 6/10
# 1405/1405 [==============================] - 257s 183ms/step - loss: 0.0113 - accuracy: 0.4315 - val_loss: 0.0677 - val_accuracy: 0.4911
# Epoch 7/10
# 1405/1405 [==============================] - 259s 184ms/step - loss: 0.0084 - accuracy: 0.4298 - val_loss: 0.0657 - val_accuracy: 0.4915
# Epoch 8/10
# 1405/1405 [==============================] - 258s 184ms/step - loss: 0.0061 - accuracy: 0.4320 - val_loss: 0.0679 - val_accuracy: 0.4915
# Epoch 9/10
# 1405/1405 [==============================] - 257s 183ms/step - loss: 0.0046 - accuracy: 0.4335 - val_loss: 0.0682 - val_accuracy: 0.4915
# Epoch 10/10
# 1405/1405 [==============================] - 257s 183ms/step - loss: 0.0040 - accuracy: 0.4323 - val_loss: 0.0703 - val_accuracy: 0.4915

# %% [markdown]
# ## Evaluating model performance after fine-tuning

# %%
metrics_after_fit = calculate_metrics(model, tf_eval_dataset)
metrics_after_fit
# Out:
# 2023-07-30 02:34:06.311679: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,48]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:07.863037: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,37]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:10.285147: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,52]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:10.570100: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,17]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:10.673525: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,17]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:10.782805: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,18]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:10.893520: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,16]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:10.990572: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,51]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:11.256701: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,40]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:11.473929: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,29]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:11.631398: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,49]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:11.896373: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,46]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:12.154018: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,44]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:12.391972: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,17]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:12.500908: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,30]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:12.669712: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,19]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:12.779710: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,30]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:12.955129: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,36]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:13.149090: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,76]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:13.541269: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,24]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:13.673370: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,71]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:14.051781: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,15]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:14.141787: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,17]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:14.248091: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,14]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:14.337422: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,16]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:14.438506: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,17]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:14.545091: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,26]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:14.693318: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,36]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:14.884396: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,57]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:15.176826: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,60]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:15.489725: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,28]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:15.648925: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,36]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:15.840437: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,39]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:16.069132: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,40]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:16.285058: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,51]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:16.576025: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,33]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:16.765158: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,56]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:17.059979: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,52]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:17.343672: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,48]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:17.602349: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,47]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:17.861166: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,21]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:17.978033: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,18]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:18.085382: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,15]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:18.176771: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,20]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:18.292659: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,17]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:18.399954: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,18]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:18.504035: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,18]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:18.611570: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,19]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:18.726213: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,18]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:18.834672: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,17]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:18.943963: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,18]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:19.048731: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,17]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:19.152007: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,19]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:19.262171: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,19]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:19.372399: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,16]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:19.469526: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,36]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:19.669365: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,54]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:19.952487: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,54]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:20.234475: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,50]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:20.497190: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,16]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:20.597441: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,27]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:20.747383: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,36]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:20.939267: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,36]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:21.132397: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,33]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:21.318220: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,25]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:21.451365: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,42]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:21.678692: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,45]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:21.914437: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,28]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:22.066300: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,18]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:22.178681: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,43]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:22.412280: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,54]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:22.694110: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,57]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:22.975734: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,95]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:23.497704: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,58]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:23.799488: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,46]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:24.034611: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,51]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:24.293154: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,54]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:24.568640: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,71]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:24.923047: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,48]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:25.150410: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,36]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:25.341978: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,41]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:25.547168: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,39]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:25.745708: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,51]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:26.018480: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,44]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:26.253368: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,44]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:26.488075: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,52]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:26.758306: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,50]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:27.021989: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,48]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:27.257046: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,41]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:27.466400: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,48]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:27.706516: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,37]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:27.899535: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,51]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:28.167066: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,45]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:28.408167: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,62]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:28.727786: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,52]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:29.004130: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,59]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:29.328772: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,48]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:29.563516: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,51]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:29.848911: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,69]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:30.189658: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,58]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:30.488970: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,58]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:30.807120: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,54]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:31.086203: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,45]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:31.334451: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,65]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:31.663945: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,55]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:31.948323: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,66]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:32.303925: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,40]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:32.516021: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,50]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:32.784891: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,52]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:33.044905: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,67]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:33.384579: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,48]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:33.634355: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,61]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:33.936472: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,55]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:34.213603: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,65]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:34.547557: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,54]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:34.820917: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,54]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:35.085165: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,58]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:35.389417: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,59]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:35.692427: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,49]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:35.938392: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,68]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:36.269643: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,35]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:36.458695: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,50]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:36.720566: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,56]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:36.998807: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,35]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:37.190393: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,43]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:37.422799: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,37]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:37.611733: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,29]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:37.770520: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,56]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:38.050225: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,39]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:38.269299: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,16]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:38.367304: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,17]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:38.475947: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,31]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:38.637518: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,47]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:38.884612: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,45]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:39.129363: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,49]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:39.381173: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,39]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:39.587013: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,40]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:39.800262: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,23]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:34:39.926705: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,6]
# 	 [[{{node Placeholder/_3}}]]
# ...
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:09.351220: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,46]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:09.581331: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,60]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:09.879792: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,61]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:10.182861: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,41]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:10.390649: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,54]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:10.662282: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,62]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:10.964336: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,54]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:11.237302: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,51]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:11.495556: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,49]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:11.746833: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,83]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:12.152715: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,45]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:12.377492: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,50]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:12.634601: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,50]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:12.896218: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,41]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:13.098514: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,54]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:13.365251: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,45]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:13.601755: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,42]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:13.807709: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,42]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:14.019088: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,57]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:14.309872: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,49]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:14.574971: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,43]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:14.798028: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,50]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:15.069338: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,38]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:15.259193: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,49]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:15.504662: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,66]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:15.840205: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,53]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:16.109335: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,66]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:16.441998: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,68]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:16.793571: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,34]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:16.968695: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,56]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:17.249668: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,36]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:17.442633: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,57]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:17.715472: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,59]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:18.022402: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,72]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:18.401661: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,50]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:18.650383: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,53]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:18.909281: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,43]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:19.139850: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,59]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:19.432884: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,53]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:19.713596: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,38]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:19.907088: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,57]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:20.184847: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,43]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:20.405497: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,43]
# 	 [[{{node Placeholder/_3}}]]
# 2023-07-30 02:35:20.619466: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype int64 and shape [10,55]
# 	 [[{{node Placeholder/_3}}]]
# {'LOC': {'precision': 0.9631635969664138,
#   'recall': 0.9678824169842134,
#   'f1': 0.9655172413793104,
#   'number': 1837},
#  'MISC': {'precision': 0.8700623700623701,
#   'recall': 0.9078091106290672,
#   'f1': 0.8885350318471338,
#   'number': 922},
#  'ORG': {'precision': 0.9053168244719592,
#   'recall': 0.9269202087994034,
#   'f1': 0.9159911569638909,
#   'number': 1341},
#  'PER': {'precision': 0.9610458911419424,
#   'recall': 0.9777415852334419,
#   'f1': 0.9693218514531755,
#   'number': 1842},
#  'overall_precision': 0.934599504541701,
#  'overall_recall': 0.9523729384045776,
#  'overall_f1': 0.9434025172959907,
#  'overall_accuracy': 0.9865632542532525}

# %% [markdown]
# ## Model test - random ten test dataset predictions

# %%
from transformers import pipeline
import random

model.load_weights(BEST_MODEL_CHECKPOINT)
token_classifier = pipeline(
    "token-classification", model=model, aggregation_strategy="simple", tokenizer=tokenizer
)

max_length = len(raw_datasets['test'])


for i in range(10):
    id = random.randint(0, max_length)
    drawn_data = raw_datasets["test"][id]
    # print(drawn_data)
    print ("ID: ", drawn_data["id"], "Input: ", drawn_data["tokens"])
    print ("Expected: ", [id2label[x] for x in drawn_data["ner_tags"]])
    print ("Output:", token_classifier(drawn_data['tokens']))
    print("_______________________________________________________________")
# Out:
# ID:  2972 Input:  ['Crystal', 'Palace', '21', '9', '8', '4', '46', '22', '35']
# Expected:  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Output: [[{'entity_group': 'ORG', 'score': 0.77750933, 'word': 'Crystal', 'start': 0, 'end': 7}], [{'entity_group': 'LOC', 'score': 0.5660404, 'word': 'Palace', 'start': 0, 'end': 6}], [], [], [], [], [], [], []]
# _______________________________________________________________
# ID:  1222 Input:  ['The', 'weather', 'in', 'the', 'capital', 'Port', 'Louis', 'was', 'heavily', 'cloudy', 'on', 'Friday', 'afternoon', 'with', 'occasional', 'showers', '.']
# Expected:  ['O', 'O', 'O', 'O', 'O', 'B-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Output: [[], [], [], [], [], [{'entity_group': 'LOC', 'score': 0.98062485, 'word': 'Port', 'start': 0, 'end': 4}], [{'entity_group': 'PER', 'score': 0.9869804, 'word': 'Louis', 'start': 0, 'end': 5}], [], [], [], [], [], [], [], [], [], []]
# _______________________________________________________________
# ID:  1666 Input:  ['Prison', 'officials', 'said', 'they', 'had', 'no', 'record', 'of', 'Mills', "'", 'official', 'conversion', ',', 'but', 'they', 'said', 'that', ',', 'on', 'May', '14', ',', '1991', ',', 'he', 'had', 'asked', 'that', 'a', 'new', 'name', ',', 'Yuhanna', 'Abdullah', 'Muhammed', ',', 'be', 'added', 'to', 'his', 'prison', 'file', ',', 'which', 'is', 'usually', 'an', 'indication', 'of', 'a', 'conversion', 'to', 'Islam', '.']
# Expected:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O']
# Output: [[], [], [], [], [], [], [], [], [{'entity_group': 'ORG', 'score': 0.97696495, 'word': 'Mills', 'start': 0, 'end': 5}], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [{'entity_group': 'PER', 'score': 0.9937674, 'word': 'Yuhanna', 'start': 0, 'end': 7}], [{'entity_group': 'PER', 'score': 0.9927079, 'word': 'Abdullah', 'start': 0, 'end': 8}], [{'entity_group': 'PER', 'score': 0.99585646, 'word': 'Muhammed', 'start': 0, 'end': 8}], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [{'entity_group': 'LOC', 'score': 0.8167283, 'word': 'Islam', 'start': 0, 'end': 5}], []]
# _______________________________________________________________
# ID:  2167 Input:  ['The', 'group', ',', 'known', 'as', 'Munich', 'Re', ',', 'plans', 'to', 'seek', 'approval', 'for', 'the', 'move', 'at', 'its', 'shareholders', "'", 'meeting', 'today', '.']
# Expected:  ['O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Output: [[], [], [], [], [], [{'entity_group': 'LOC', 'score': 0.99707305, 'word': 'Munich', 'start': 0, 'end': 6}], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# _______________________________________________________________
# ID:  2722 Input:  ['Grunde', 'Njos', '(', 'Norway', ')', '37.49', ';', '4', '.']
# Expected:  ['B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# Output: [[{'entity_group': 'PER', 'score': 0.9726258, 'word': 'Grunde', 'start': 0, 'end': 6}], [{'entity_group': 'PER', 'score': 0.9900685, 'word': 'Njos', 'start': 0, 'end': 4}], [], [{'entity_group': 'LOC', 'score': 0.9994591, 'word': 'Norway', 'start': 0, 'end': 6}], [], [], [], [], []]
# _______________________________________________________________
# ID:  3134 Input:  ['Penalties', ':', 'Burke', '(', '2', ')', '.']
# Expected:  ['O', 'O', 'B-PER', 'O', 'O', 'O', 'O']
# Output: [[], [], [{'entity_group': 'PER', 'score': 0.99638486, 'word': 'Burke', 'start': 0, 'end': 5}], [], [], [], []]
# _______________________________________________________________
# ID:  2162 Input:  ['Brazil', 'was', 'in', 'seventh', 'position', 'with', '54,333', 'bags', '(', '29,055', ')', '.']
# Expected:  ['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Output: [[{'entity_group': 'LOC', 'score': 0.9995683, 'word': 'Brazil', 'start': 0, 'end': 6}], [], [], [], [], [], [], [], [], [], [], []]
# _______________________________________________________________
# ID:  2411 Input:  ['14.', 'Sybille', 'Brauner', '(', 'Germany', ')', '1:18.81']
# Expected:  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O']
# Output: [[], [{'entity_group': 'PER', 'score': 0.9970957, 'word': 'Sybille', 'start': 0, 'end': 7}], [{'entity_group': 'PER', 'score': 0.94860625, 'word': 'Brauner', 'start': 0, 'end': 7}], [], [{'entity_group': 'LOC', 'score': 0.9994574, 'word': 'Germany', 'start': 0, 'end': 7}], [], []]
# _______________________________________________________________
# ID:  2813 Input:  ['Glentoran', '10', '3', '3', '4', '18', '18', '12']
# Expected:  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Output: [[{'entity_group': 'ORG', 'score': 0.9956286, 'word': 'Glentoran', 'start': 0, 'end': 9}], [], [], [], [], [], [], []]
# _______________________________________________________________
# ID:  2668 Input:  ['Women', ':']
# Expected:  ['O', 'O']
# Output: [[], []]
# _______________________________________________________________
